# %% [markdown]
# <p style="float: right; margin-left: 20px; margin-right: 100px;">
#   <img src="../Figures/Photo_Qubit.png" width="500">
# </p>
#
# # Lancer les notebooks
#
# - [Simulation du transmon](./Simulation_transmon_solution.ipynb)
# - [Ligne de transmission](./Ligne_de_transmission_solution.ipynb)
# - [Résonateur](./Transmon_Resonator_solution.ipynb)
# - [Filtre Purcell](./Transmon_Purcell_solution.ipynb)
# - [Mesure dispersive du transmon](./Readout_transmon_solution.ipynb)
